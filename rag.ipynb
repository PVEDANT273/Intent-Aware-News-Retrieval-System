# %%
import os
import requests
from datetime import datetime, timedelta
from dotenv import load_dotenv

load_dotenv()

NEWS_API_KEY = os.getenv("NEWS_API_KEY")
BASE_URL = "https://newsapi.org/v2/everything"

def fetch_news(
    query: str,
    days: int = 3,
    language: str = "en",
    page_size: int = 20
):
    """
    Fetch news articles from NewsAPI based on a query.
    """
    if not NEWS_API_KEY:
        raise ValueError("NEWS_API_KEY not found in environment variables")

    from_date = (datetime.utcnow() - timedelta(days=days)).strftime("%Y-%m-%d")

    params = {
        "q": query,
        "from": from_date,
        "sortBy": "relevancy",
        "language": language,
        "pageSize": page_size,
        "apiKey": NEWS_API_KEY
    }

    response = requests.get(BASE_URL, params=params)
    response.raise_for_status()

    data = response.json()
    return data.get("articles", [])

# %%
def normalize_articles(articles):
    """
    Keeping the field only relevant for further processing
    """
    normalized = []
    for article in articles:
        content = article.get("content") or article.get("description")
        if not content:
            continue

        normalized.append({
            "title": article.get("title"),
            "source": article.get("source", {}).get("name"),
            "published_at": article.get("publishedAt"),
            "url": article.get("url"),
            "text": content
        })
    return normalized

# %%
raw_articles = fetch_news("artificial Intelligence")
raw_articles
# Out:
# [{'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': None,
#   'title': '1 Unstoppable Artificial Intelligence (AI) Stock to Buy Before It Soars More Than 30% in 2026, According to a Wall Street Analyst',
#   'description': None,
#   'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_c345afd1-235d-4da5-9e7f-6eb8783fad2c',
#   'urlToImage': None,
#   'publishedAt': '2026-01-19T21:25:00Z',
#   'content': "If you click 'Accept all', we and our partners, including 245 who are part of the IAB Transparency &amp; Consent Framework, will also store and / or access information on a device (in other words, us… [+1046 chars]"},
#  {'source': {'id': None, 'name': 'BBC News'},
#   'author': None,
#   'title': "Chris Pratt on new film Mercy: I asked to be locked into an executioner's chair",
#   'description': 'The Marvel star plays a detective with 90 minutes to prove to an AI judge he did not murder his wife.',
#   'url': 'https://www.bbc.com/news/articles/cy05drxx2nwo',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/cc01/live/29b46580-f09f-11f0-8122-3db3b1d47cf5.jpg',
#   'publishedAt': '2026-01-20T00:37:41Z',
#   'content': "Helen BushbyCulture reporter\r\nChris Pratt plays a police officer with just 90 minutes to prove to an AI judge he did not murder his wife\r\nBeing locked barefoot in an executioner's chair sounds uncomf… [+5772 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Alex Bitter',
#   'title': "OpenAI will focus on 'practical adoption' of AI in 2026, CFO says",
#   'description': 'OpenAI CFO Sarah Friar said the company is focused on "practical adoption" in 2026, especially in health, science, and enterprise.',
#   'url': 'https://www.businessinsider.com/openai-cfo-friar-2026-year-practical-adoption-ai-2026-1',
#   'urlToImage': 'https://i.insider.com/696e9d16e1ba468a96aa4f4b?width=1200&format=jpeg',
#   'publishedAt': '2026-01-19T22:31:29Z',
#   'content': 'OpenAI CFO Sarah FriarPATRICK T. FALLON/AFP via Getty Images\r\n<ul><li>OpenAI is focused on "practical adoption" in 2026, CFO Sarah Friar wrote.</li><li>The company sees opportunities to grow its busi… [+2122 chars]'},
#  {'source': {'id': None, 'name': 'Snopes.com'},
#   'author': 'Anna Rascouët-Paz',
#   'title': "Inspecting claim Ukraine ran 'sting operation' providing false intelligence to US that was then leaked to Russia",
#   'description': 'The rumor appeared to stem from a mistranslation of an interview on French news television.',
#   'url': 'https://www.snopes.com/news/2026/01/19/ukraine-intelligence-us-leaks-russia/',
#   'urlToImage': 'https://s.yimg.com/os/en/snopes_632/a0c5814f1411c89454209d5f6c11c04e',
#   'publishedAt': '2026-01-20T00:27:00Z',
#   'content': '<ul><li>After French President Emmanuel Macron said France was now providing two-thirds of all intelligence to Ukraine on Jan. 15, 2026, a rumor gained traction that this was because Ukraine had give… [+6738 chars]'},
#  {'source': {'id': None, 'name': 'Windows Central'},
#   'author': 'jez@windowscentral.com (Jez Corden) , Jez Corden',
#   'title': 'Adobe and other SaaS stocks are taking a beating — as traditional software companies struggle in the AI era ',
#   'description': 'Is the era of Photoshop over? The stock market seems unconvinced of many traditional SaaS companies offerings as artificial intelligence takes center stage.',
#   'url': 'https://www.windowscentral.com/microsoft/adobe-and-other-saas-stocks-taking-a-beating-as-traditional-software-companies-struggle-in-the-ai-era',
#   'urlToImage': 'https://cdn.mos.cms.futurecdn.net/HFVSPQ3HsxE5xUjgS3bDDd-1536-80.png',
#   'publishedAt': '2026-01-19T16:57:24Z',
#   'content': 'Is the era of Photoshop ending? You might be forgiven for thinking so.\r\nI\'m sure we\'ll all be playing the world\'s smallest violin for Adobe. After years of locking users in with aggressive "cancellat… [+8790 chars]'},
#  {'source': {'id': None, 'name': 'Psychology Today'},
#   'author': 'Cornelia C. Walther Ph.D.',
#   'title': 'Artificial Intelligence Mirrors Natural Intelligence',
#   'description': 'AI mirrors human abilities, literally. In this new era, the most valuable technological skills for hybrid citizens will remain knowledge, critical thinking, and a quirky mind.',
#   'url': 'https://www.psychologytoday.com/us/blog/harnessing-hybrid-intelligence/202601/artificial-intelligence-mirrors-natural-intelligence',
#   'urlToImage': 'https://cdn2.psychologytoday.com/assets/styles/manual_crop_1_91_1_1528x800/public/teaser_image/blog_entry/2026-01/Gemini_Generated_Image_pls66pls66pls66p.png.jpg?itok=ZIQc_igG',
#   'publishedAt': '2026-01-18T20:53:03Z',
#   'content': 'For the past three years, the conversation around artificial intelligence has been dominated by a single, anxious question: What will be left for us to do? As large language models began writing code… [+6725 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Aaron Mok,Jyoti Mann,Grace Eliza Goodwin,Brent D. Griffiths',
#   'title': 'AGI? GPUs? Learn the definitions of the most common AI terms to enter our vocabulary',
#   'description': "The rise of AI has given us an entirely new vocabulary. Here's a list of the top AI terms you need to learn, in alphabetical order.",
#   'url': 'https://www.businessinsider.com/ai-terms-definitions-vocabulary-2026',
#   'urlToImage': 'https://i.insider.com/65847249cefc010bea265374?width=1200&format=jpeg',
#   'publishedAt': '2026-01-18T09:14:01Z',
#   'content': 'Companies of all sizes are looking to hire workers who know how to use AI.Sebastien Bozon/Getty Images\r\n<ul><li>Do you know what LLM even is? How about a GPU? A new vocabulary has emerged with the ri… [+13955 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'Faizan Farooque',
#   'title': 'Nvidia Suppliers Pause Output After China Blocks H200 Chips',
#   'description': 'Export suspension underscores rising trade tension over AI hardware.',
#   'url': 'https://finance.yahoo.com/news/nvidia-suppliers-pause-output-china-151839971.html',
#   'urlToImage': 'https://s.yimg.com/os/en/us.finance.gurufocus/528af7acf1b685a79f0a0ee8c34ab69c',
#   'publishedAt': '2026-01-19T15:18:39Z',
#   'content': "This article first appeared on GuruFocus.\r\nNvidia (NVDA, Financials) suppliers have paused output of components for the company's H200 artificial intelligence chips after Chinese customs authorities … [+876 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Bradley Saacks',
#   'title': "China-focused hedge funds surged in 2025. Here's who won big.",
#   'description': 'The average fund invested in China in 2025 made close to 18%, according to Hedge Fund Research.',
#   'url': 'https://www.businessinsider.com/hedge-funds-china-performance-2025-2026-1',
#   'urlToImage': 'https://i.insider.com/696913e104eda4732f2f2337?width=1200&format=jpeg',
#   'publishedAt': '2026-01-18T11:51:01Z',
#   'content': "Chinese leader Xi Jinping and his ruling party have pushed to stimulate China's economy.Xie Huanchi/Xinhua via Getty Images\r\n<ul><li>Hedge funds betting big on China generated strong returns last yea… [+2934 chars]"},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'Thibault Spirlet',
#   'title': 'Ben Horowitz says AI could spark a post-electricity leap in living standards — but risk eroding purpose',
#   'description': 'Andreessen Horowitz cofounder Ben Horowitz said AI will boost life quality but warns a frictionless future could leave people searching for meaning.',
#   'url': 'https://www.businessinsider.com/ben-horowitz-ai-could-boost-living-standards-like-electricity-2026-1',
#   'urlToImage': 'https://i.insider.com/696e092aa645d118818794c5?width=1200&format=jpeg',
#   'publishedAt': '2026-01-19T12:26:25Z',
#   'content': 'Ben Horowitz says AI could deliver an electricity-scale leap in living standards — while quietly threatening how humans find meaning.Phillip Faraone/Getty Images for WIRED\r\n<ul><li>Ben Horowitz said … [+2834 chars]'},
#  {'source': {'id': 'the-wall-street-journal',
#    'name': 'The Wall Street Journal'},
#   'author': 'Jiahui Huang and Fabiana Negrin Ochoa',
#   'title': 'Micron to Buy Taiwan Plant for $1.8 Billion',
#   'description': 'The Boise, Idaho-based company plans to acquire the Taiwanese chip-making site to meet surging demand for memory-storage products.',
#   'url': 'https://www.wsj.com/business/deals/micron-to-buy-taiwan-plant-for-1-8-billion-5eef73e5',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/DyvrK1XPG49YaeDRCU7d9w--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD02MDA-/https://media.zenfs.com/en/the_wall_street_journal_hosted_996/e7a88b57d89bf1ca08c7c3a434b7e209',
#   'publishedAt': '2026-01-19T06:58:00Z',
#   'content': 'The U.S. company has signed a letter of intent to acquire an advanced semiconductor manufacturing fabrication site from Powerchip Semiconductor Manufacturing Corp. - Maxim Shemetov/Reuters\r\nMicron Te… [+2477 chars]'},
#  {'source': {'id': None, 'name': 'Android Central'},
#   'author': 'bradypsnyder@gmail.com (Brady Snyder) , Brady Snyder',
#   'title': 'RAM is the only phone spec that matters in 2026',
#   'description': 'The availability of many on-device AI features is directly correlated to the amount of RAM your phone has, making memory the most important spec.',
#   'url': 'https://www.androidcentral.com/phones/google-pixel/ram-is-the-only-phone-spec-that-matters-in-2026',
#   'urlToImage': 'https://cdn.mos.cms.futurecdn.net/TetbMwB5dn8TSKX32EMFjP-2560-80.jpg',
#   'publishedAt': '2026-01-19T16:11:00Z',
#   'content': "It's no secret that smartphones are incredibly mature, and the days of justifying annual upgrades are over. Processors are fast, displays are crisp, cameras are sharp, and crucially, phone makers are… [+6249 chars]"},
#  {'source': {'id': None, 'name': 'Corporateeurope.org'},
#   'author': None,
#   'title': "Article by article, how Big Tech shaped the EU's roll-back of digital rights",
#   'description': "In a new analysis we trace Big Tech's fingerprints on the Digital Omnibus proposals - a major deregulation of EU digital laws including the GDPR and the AI Act. They are helped in this attempt by the Trump administration and the European far right.",
#   'url': 'https://corporateeurope.org/en/2026/01/article-article-how-big-tech-shaped-eus-roll-back-digital-rights',
#   'urlToImage': 'https://corporateeurope.org/sites/default/files/styles/facebook/public/2026-01/IMG_0198%281%29.jpeg?itok=fDlqq4iS',
#   'publishedAt': '2026-01-19T12:53:28Z',
#   'content': 'At the end of November 2025, Ursula von der Leyen gave Trump and his tech oligarchs an early Christmas present: an unprecedented attack on digital rights. In its so-called Digital Omnibus, the Europe… [+2472 chars]'},
#  {'source': {'id': 'techradar', 'name': 'TechRadar'},
#   'author': 'Khalid Aziz',
#   'title': 'Responsible innovation: what 2026 should look like for businesses harnessing AI',
#   'description': 'Businesses harnessing artificial intelligence should do so with governance, data integrity and investing in people.',
#   'url': 'https://www.techradar.com/pro/responsible-innovation-what-2026-should-look-like-for-businesses-harnessing-ai',
#   'urlToImage': 'https://cdn.mos.cms.futurecdn.net/LJ7xXkLMRdgVo8vT4Ccgrb-2560-80.jpg',
#   'publishedAt': '2026-01-18T09:00:00Z',
#   'content': 'B2B marketing is entering a new phase, defined not by speed or scale alone, but by responsibility, trust and more integrated ways of working.\r\nAs businesses face tighter budgets, longer sales cycles … [+6114 chars]'},
#  {'source': {'id': None, 'name': 'TalkAndroid'},
#   'author': 'Ethan Collins',
#   'title': 'AI secretly spying on your emails? The simple trick to stop it instantly',
#   'description': 'Is artificial intelligence silently peeking into your inbox while you sip your morning coffee? If you’re using Gmail, perhaps. But before you combust in',
#   'url': 'https://www.talkandroid.com/519803-ai-secretly-spying-on-your-emails-the-simple-trick-to-stop-it-instantly/',
#   'urlToImage': 'https://www.talkandroid.com/wp-content/uploads/2025/12/ai-secretly-spying-on-your-emails-the-simple-trick-to-stop-it-instantly.webp',
#   'publishedAt': '2026-01-18T16:30:00Z',
#   'content': 'Is artificial intelligence silently peeking into your inbox while you sip your morning coffee? If youre using Gmail, perhaps. But before you combust in digital rage, heres the unvarnished truth about… [+3817 chars]'},
#  {'source': {'id': None, 'name': 'Psychology Today'},
#   'author': 'John Nosta',
#   'title': 'When AI Assumes We Already Know',
#   'description': 'Artificial intelligence speaks as if the destination were always known, tempting us to mistake arrival for understanding.',
#   'url': 'https://www.psychologytoday.com/us/blog/the-digital-self/202601/when-ai-assumes-we-already-know',
#   'urlToImage': 'https://cdn2.psychologytoday.com/assets/styles/manual_crop_1_91_1_1528x800/public/field_blog_entry_images/2026-01/AIPath.png.jpg?itok=s1kDn1DQ',
#   'publishedAt': '2026-01-19T17:30:37Z',
#   'content': "There's an interesting, yet not well-realized, assumption built into every conversation we have with a large language model (LLM). It's never stated, but it's in the mathematics that drives the excha… [+5453 chars]"},
#  {'source': {'id': None, 'name': 'Slashdot.org'},
#   'author': 'EditorDavid',
#   'title': 'Retailers Rush to Implement AI-Assisted Shopping and Orders',
#   'description': 'This week Google "unveiled a set of tools for retailers that helps them roll out AI agents," reports the Wall Street Journal,\nThe new retail AI agents, which help shoppers find their desired items, provide customer support and let people order food at restaur…',
#   'url': 'https://slashdot.org/story/26/01/18/0631239/retailers-rush-to-implement-ai-assisted-shopping-and-orders',
#   'urlToImage': 'https://a.fsdn.com/sd/topics/ai_64.png',
#   'publishedAt': '2026-01-18T08:54:00Z',
#   'content': 'The new retail AI agents, which help shoppers find their desired items, provide customer support and let people order food at restaurants, are part of what Alphabet-owned Google calls Gemini Enterpri… [+650 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': 'ELAINE KURTENBACH',
#   'title': 'US futures sink after Trump warns of higher tariffs for 8 countries over Greenland issue',
#   'description': 'U.S. stock futures skidded Monday after U.S. President Donald Trump threatened to slap a 10% extra tariff on imports from eight European countries due to...',
#   'url': 'https://www.yahoo.com/news/articles/us-futures-sink-trump-warns-064219353.html',
#   'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/mCMUIzfFFVZ3240cGUTrLg--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA7Y2Y9d2VicA--/https://media.zenfs.com/en/ap.org/2c86438e0201113924f8447544ad63a8',
#   'publishedAt': '2026-01-19T06:42:19Z',
#   'content': 'BANGKOK (AP) U.S. stock futures skidded Monday after U.S. President Donald Trump threatened to slap a 10% extra tariff on imports from eight European countries due to their opposition to his desire t… [+3982 chars]'},
#  {'source': {'id': None, 'name': 'Yahoo Entertainment'},
#   'author': None,
#   'title': 'Could This Be the Most Misunderstood Artificial Intelligence (AI) Stock on the Market?',
#   'description': None,
#   'url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_785aecb8-cb0b-4af9-bd0c-60a90f415382',
#   'urlToImage': None,
#   'publishedAt': '2026-01-19T11:30:00Z',
#   'content': "If you click 'Accept all', we and our partners, including 245 who are part of the IAB Transparency &amp; Consent Framework, will also store and / or access information on a device (in other words, us… [+1046 chars]"},
#  {'source': {'id': None, 'name': 'Yanko Design'},
#   'author': 'Pooja Khanna Tyagi',
#   'title': '5 AI Devices That Just Made Smartphones Look Obsolete in 2026',
#   'description': '5 AI Devices That Just Made Smartphones Look Obsolete in 2026The year 2026 marks a historic pivot in personal technology. We are moving past the era of the “AI chatbot” trapped inside a website and...',
#   'url': 'https://www.yankodesign.com/2026/01/18/5-ai-devices-that-just-made-smartphones-look-obsolete-in-2026/',
#   'urlToImage': 'https://www.yankodesign.com/images/design_news/2026/01/ai-in-your-pocket-why-next-gen-devices-are-taking-over-2026/AI-Devices_Gadgets_2026_1.jpg',
#   'publishedAt': '2026-01-18T12:40:51Z',
#   'content': 'The year 2026 marks a historic pivot in personal technology. We are moving past the era of the “AI chatbot” trapped inside a website and entering the age of ambient hardware. While 2025 was defined b… [+10759 chars]'}]

# %%
len(raw_articles)
# Out:
# 20

# %%
docs = []
for article in raw_articles:
    docs.append({'Title': article['title'],
                 'Content': article['content'],
                 'Description': article['description'],
                 'Source': article['source']['name'],
                 "Url": article['url']})
    
docs
# Out:
# [{'Title': '1 Unstoppable Artificial Intelligence (AI) Stock to Buy Before It Soars More Than 30% in 2026, According to a Wall Street Analyst',
#   'Content': "If you click 'Accept all', we and our partners, including 245 who are part of the IAB Transparency &amp; Consent Framework, will also store and / or access information on a device (in other words, us… [+1046 chars]",
#   'Description': None,
#   'Source': 'Yahoo Entertainment',
#   'Url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_c345afd1-235d-4da5-9e7f-6eb8783fad2c'},
#  {'Title': "Chris Pratt on new film Mercy: I asked to be locked into an executioner's chair",
#   'Content': "Helen BushbyCulture reporter\r\nChris Pratt plays a police officer with just 90 minutes to prove to an AI judge he did not murder his wife\r\nBeing locked barefoot in an executioner's chair sounds uncomf… [+5772 chars]",
#   'Description': 'The Marvel star plays a detective with 90 minutes to prove to an AI judge he did not murder his wife.',
#   'Source': 'BBC News',
#   'Url': 'https://www.bbc.com/news/articles/cy05drxx2nwo'},
#  {'Title': "OpenAI will focus on 'practical adoption' of AI in 2026, CFO says",
#   'Content': 'OpenAI CFO Sarah FriarPATRICK T. FALLON/AFP via Getty Images\r\n<ul><li>OpenAI is focused on "practical adoption" in 2026, CFO Sarah Friar wrote.</li><li>The company sees opportunities to grow its busi… [+2122 chars]',
#   'Description': 'OpenAI CFO Sarah Friar said the company is focused on "practical adoption" in 2026, especially in health, science, and enterprise.',
#   'Source': 'Business Insider',
#   'Url': 'https://www.businessinsider.com/openai-cfo-friar-2026-year-practical-adoption-ai-2026-1'},
#  {'Title': "Inspecting claim Ukraine ran 'sting operation' providing false intelligence to US that was then leaked to Russia",
#   'Content': '<ul><li>After French President Emmanuel Macron said France was now providing two-thirds of all intelligence to Ukraine on Jan. 15, 2026, a rumor gained traction that this was because Ukraine had give… [+6738 chars]',
#   'Description': 'The rumor appeared to stem from a mistranslation of an interview on French news television.',
#   'Source': 'Snopes.com',
#   'Url': 'https://www.snopes.com/news/2026/01/19/ukraine-intelligence-us-leaks-russia/'},
#  {'Title': 'Adobe and other SaaS stocks are taking a beating — as traditional software companies struggle in the AI era ',
#   'Content': 'Is the era of Photoshop ending? You might be forgiven for thinking so.\r\nI\'m sure we\'ll all be playing the world\'s smallest violin for Adobe. After years of locking users in with aggressive "cancellat… [+8790 chars]',
#   'Description': 'Is the era of Photoshop over? The stock market seems unconvinced of many traditional SaaS companies offerings as artificial intelligence takes center stage.',
#   'Source': 'Windows Central',
#   'Url': 'https://www.windowscentral.com/microsoft/adobe-and-other-saas-stocks-taking-a-beating-as-traditional-software-companies-struggle-in-the-ai-era'},
#  {'Title': 'Artificial Intelligence Mirrors Natural Intelligence',
#   'Content': 'For the past three years, the conversation around artificial intelligence has been dominated by a single, anxious question: What will be left for us to do? As large language models began writing code… [+6725 chars]',
#   'Description': 'AI mirrors human abilities, literally. In this new era, the most valuable technological skills for hybrid citizens will remain knowledge, critical thinking, and a quirky mind.',
#   'Source': 'Psychology Today',
#   'Url': 'https://www.psychologytoday.com/us/blog/harnessing-hybrid-intelligence/202601/artificial-intelligence-mirrors-natural-intelligence'},
#  {'Title': 'AGI? GPUs? Learn the definitions of the most common AI terms to enter our vocabulary',
#   'Content': 'Companies of all sizes are looking to hire workers who know how to use AI.Sebastien Bozon/Getty Images\r\n<ul><li>Do you know what LLM even is? How about a GPU? A new vocabulary has emerged with the ri… [+13955 chars]',
#   'Description': "The rise of AI has given us an entirely new vocabulary. Here's a list of the top AI terms you need to learn, in alphabetical order.",
#   'Source': 'Business Insider',
#   'Url': 'https://www.businessinsider.com/ai-terms-definitions-vocabulary-2026'},
#  {'Title': 'Nvidia Suppliers Pause Output After China Blocks H200 Chips',
#   'Content': "This article first appeared on GuruFocus.\r\nNvidia (NVDA, Financials) suppliers have paused output of components for the company's H200 artificial intelligence chips after Chinese customs authorities … [+876 chars]",
#   'Description': 'Export suspension underscores rising trade tension over AI hardware.',
#   'Source': 'Yahoo Entertainment',
#   'Url': 'https://finance.yahoo.com/news/nvidia-suppliers-pause-output-china-151839971.html'},
#  {'Title': "China-focused hedge funds surged in 2025. Here's who won big.",
#   'Content': "Chinese leader Xi Jinping and his ruling party have pushed to stimulate China's economy.Xie Huanchi/Xinhua via Getty Images\r\n<ul><li>Hedge funds betting big on China generated strong returns last yea… [+2934 chars]",
#   'Description': 'The average fund invested in China in 2025 made close to 18%, according to Hedge Fund Research.',
#   'Source': 'Business Insider',
#   'Url': 'https://www.businessinsider.com/hedge-funds-china-performance-2025-2026-1'},
#  {'Title': 'Ben Horowitz says AI could spark a post-electricity leap in living standards — but risk eroding purpose',
#   'Content': 'Ben Horowitz says AI could deliver an electricity-scale leap in living standards — while quietly threatening how humans find meaning.Phillip Faraone/Getty Images for WIRED\r\n<ul><li>Ben Horowitz said … [+2834 chars]',
#   'Description': 'Andreessen Horowitz cofounder Ben Horowitz said AI will boost life quality but warns a frictionless future could leave people searching for meaning.',
#   'Source': 'Business Insider',
#   'Url': 'https://www.businessinsider.com/ben-horowitz-ai-could-boost-living-standards-like-electricity-2026-1'},
#  {'Title': 'Micron to Buy Taiwan Plant for $1.8 Billion',
#   'Content': 'The U.S. company has signed a letter of intent to acquire an advanced semiconductor manufacturing fabrication site from Powerchip Semiconductor Manufacturing Corp. - Maxim Shemetov/Reuters\r\nMicron Te… [+2477 chars]',
#   'Description': 'The Boise, Idaho-based company plans to acquire the Taiwanese chip-making site to meet surging demand for memory-storage products.',
#   'Source': 'The Wall Street Journal',
#   'Url': 'https://www.wsj.com/business/deals/micron-to-buy-taiwan-plant-for-1-8-billion-5eef73e5'},
#  {'Title': 'RAM is the only phone spec that matters in 2026',
#   'Content': "It's no secret that smartphones are incredibly mature, and the days of justifying annual upgrades are over. Processors are fast, displays are crisp, cameras are sharp, and crucially, phone makers are… [+6249 chars]",
#   'Description': 'The availability of many on-device AI features is directly correlated to the amount of RAM your phone has, making memory the most important spec.',
#   'Source': 'Android Central',
#   'Url': 'https://www.androidcentral.com/phones/google-pixel/ram-is-the-only-phone-spec-that-matters-in-2026'},
#  {'Title': "Article by article, how Big Tech shaped the EU's roll-back of digital rights",
#   'Content': 'At the end of November 2025, Ursula von der Leyen gave Trump and his tech oligarchs an early Christmas present: an unprecedented attack on digital rights. In its so-called Digital Omnibus, the Europe… [+2472 chars]',
#   'Description': "In a new analysis we trace Big Tech's fingerprints on the Digital Omnibus proposals - a major deregulation of EU digital laws including the GDPR and the AI Act. They are helped in this attempt by the Trump administration and the European far right.",
#   'Source': 'Corporateeurope.org',
#   'Url': 'https://corporateeurope.org/en/2026/01/article-article-how-big-tech-shaped-eus-roll-back-digital-rights'},
#  {'Title': 'Responsible innovation: what 2026 should look like for businesses harnessing AI',
#   'Content': 'B2B marketing is entering a new phase, defined not by speed or scale alone, but by responsibility, trust and more integrated ways of working.\r\nAs businesses face tighter budgets, longer sales cycles … [+6114 chars]',
#   'Description': 'Businesses harnessing artificial intelligence should do so with governance, data integrity and investing in people.',
#   'Source': 'TechRadar',
#   'Url': 'https://www.techradar.com/pro/responsible-innovation-what-2026-should-look-like-for-businesses-harnessing-ai'},
#  {'Title': 'AI secretly spying on your emails? The simple trick to stop it instantly',
#   'Content': 'Is artificial intelligence silently peeking into your inbox while you sip your morning coffee? If youre using Gmail, perhaps. But before you combust in digital rage, heres the unvarnished truth about… [+3817 chars]',
#   'Description': 'Is artificial intelligence silently peeking into your inbox while you sip your morning coffee? If you’re using Gmail, perhaps. But before you combust in',
#   'Source': 'TalkAndroid',
#   'Url': 'https://www.talkandroid.com/519803-ai-secretly-spying-on-your-emails-the-simple-trick-to-stop-it-instantly/'},
#  {'Title': 'When AI Assumes We Already Know',
#   'Content': "There's an interesting, yet not well-realized, assumption built into every conversation we have with a large language model (LLM). It's never stated, but it's in the mathematics that drives the excha… [+5453 chars]",
#   'Description': 'Artificial intelligence speaks as if the destination were always known, tempting us to mistake arrival for understanding.',
#   'Source': 'Psychology Today',
#   'Url': 'https://www.psychologytoday.com/us/blog/the-digital-self/202601/when-ai-assumes-we-already-know'},
#  {'Title': 'Retailers Rush to Implement AI-Assisted Shopping and Orders',
#   'Content': 'The new retail AI agents, which help shoppers find their desired items, provide customer support and let people order food at restaurants, are part of what Alphabet-owned Google calls Gemini Enterpri… [+650 chars]',
#   'Description': 'This week Google "unveiled a set of tools for retailers that helps them roll out AI agents," reports the Wall Street Journal,\nThe new retail AI agents, which help shoppers find their desired items, provide customer support and let people order food at restaur…',
#   'Source': 'Slashdot.org',
#   'Url': 'https://slashdot.org/story/26/01/18/0631239/retailers-rush-to-implement-ai-assisted-shopping-and-orders'},
#  {'Title': 'US futures sink after Trump warns of higher tariffs for 8 countries over Greenland issue',
#   'Content': 'BANGKOK (AP) U.S. stock futures skidded Monday after U.S. President Donald Trump threatened to slap a 10% extra tariff on imports from eight European countries due to their opposition to his desire t… [+3982 chars]',
#   'Description': 'U.S. stock futures skidded Monday after U.S. President Donald Trump threatened to slap a 10% extra tariff on imports from eight European countries due to...',
#   'Source': 'Yahoo Entertainment',
#   'Url': 'https://www.yahoo.com/news/articles/us-futures-sink-trump-warns-064219353.html'},
#  {'Title': 'Could This Be the Most Misunderstood Artificial Intelligence (AI) Stock on the Market?',
#   'Content': "If you click 'Accept all', we and our partners, including 245 who are part of the IAB Transparency &amp; Consent Framework, will also store and / or access information on a device (in other words, us… [+1046 chars]",
#   'Description': None,
#   'Source': 'Yahoo Entertainment',
#   'Url': 'https://consent.yahoo.com/v2/collectConsent?sessionId=1_cc-session_785aecb8-cb0b-4af9-bd0c-60a90f415382'},
#  {'Title': '5 AI Devices That Just Made Smartphones Look Obsolete in 2026',
#   'Content': 'The year 2026 marks a historic pivot in personal technology. We are moving past the era of the “AI chatbot” trapped inside a website and entering the age of ambient hardware. While 2025 was defined b… [+10759 chars]',
#   'Description': '5 AI Devices That Just Made Smartphones Look Obsolete in 2026The year 2026 marks a historic pivot in personal technology. We are moving past the era of the “AI chatbot” trapped inside a website and...',
#   'Source': 'Yanko Design',
#   'Url': 'https://www.yankodesign.com/2026/01/18/5-ai-devices-that-just-made-smartphones-look-obsolete-in-2026/'}]

# %%
if __name__ == "__main__":
    topic = "Global Warming and Climate Change"
    raw_articles = fetch_news(topic)
    clean_articles = normalize_articles(raw_articles)

    print(f"Fetched {len(clean_articles)} articles\n")

    for i, article in enumerate(clean_articles[:3], 1):
        print(f"{i}. {article['title']}")
        print(f"   Source: {article['source']}")
        print(f"   URL: {article['url']}\n")
# Out:
# Fetched 19 articles
#
# 1. Superintelligence Is Not the Answer to Climate Change
#    Source: Project Syndicate
#    URL: https://www.project-syndicate.org/commentary/ai-superintelligence-will-not-solve-climate-crisis-once-tipping-points-crossed-by-alex-friedman-1-2026-01
#
# 2. A huge iceberg becomes a deadly trap for penguins
#    Source: Popular Science
#    URL: http://www.popsci.com/environment/iceberg-traps-penguins-antarctica/
#
# 3. What Can We Do for the 250 Million and Counting Displaced by the Environmental Crisis?
#    Source: Nakedcapitalism.com
#    URL: https://www.nakedcapitalism.com/2026/01/what-can-we-do-for-the-250-million-and-counting-displaced-by-the-environmental-crisis.html

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    separators=["\n\n", "\n", " ", ""]
)

# %%
from langchain_core.documents import Document
    
def articles_to_documents(articles, topic):
    docs = []

    for article in articles:
        splits = text_splitter.split_text(article["text"])

        for split in splits:
            docs.append(
                Document(
                    page_content=split,
                    metadata={
                        "title": article["title"],
                        "source": article["source"],
                        "url": article["url"],
                        "topic": topic,
                        "date": article["published_at"][:10]
                    }
                )
            )

    return docs

# %%
topic = "Indian income tax policy"

# Convert articles -> chunked Documents
documents = articles_to_documents(
    articles=clean_articles,   # output from NewsAPI normalization
    topic=topic
)

print(f"Total document chunks created: {len(documents)}")
# Out:
# Total document chunks created: 19

# %%
from langchain_community.embeddings import OllamaEmbeddings

embeddings = OllamaEmbeddings(
    model="mxbai-embed-large"
)

test_vec = embeddings.embed_query("Income tax changes in India")
len(test_vec)
# Out:
# 1024

# %%
from langchain_community.vectorstores import Chroma

# Create / load persistent ChromaDB
vectorstore = Chroma.from_documents(
    documents=documents,              # output from articles_to_documents(...)
    embedding=embeddings,              # OllamaEmbeddings (mxbai-embed-large)
    persist_directory="./chroma_db"    # folder on disk
)

# Persist to disk
vectorstore.persist()

print(f"Stored {len(documents)} chunks in ChromaDB")
# Out:
# KeyboardInterrupt

# %%
retriever = vectorstore.as_retriever(
    search_type = "similarity",
    search_kwargs={"k": 4}   # top-4 most relevant chunks
)

# %%
topic = "Weather Patterns"
intent = "impact on farmers growing onions"

query = f"{topic}. Focus on {intent}."

# %%
docs = retriever.invoke(query)

print(f"Retrieved {len(docs)} chunks")
# Out:
# Retrieved 4 chunks

# %%
docs
# Out:
# [Document(metadata={'title': 'It’s a Gas', 'date': '2025-12-25', 'url': 'http://www.nybooks.com/articles/2026/01/15/its-a-gas-the-story-of-co2-mckibben/', 'source': 'The New York Review of Books', 'topic': 'Indian income tax policy'}, page_content='I’m writing this in the last days of the northern hemisphere’s autumn in 2025. Over recent weeks we’ve seen a hurricane hit Jamaica with wind speeds a few hundred feet above sea level topping 250 mil… [+17629 chars]'),
#  Document(metadata={'source': 'NPR', 'url': 'https://www.npr.org/2025/12/24/nx-s1-5620997/2025-hurricane-season-storm-climate-melissa-category-5', 'topic': 'Indian income tax policy', 'title': "What does climate change look like? This year's hurricane season is one example", 'date': '2025-12-24'}, page_content='The 2025 hurricane season was a study in contrasts.\r\nIn one way, it felt very quiet in the United States. No storms made landfall in the U.S. for the first time since 2015. And, for about three weeks… [+2789 chars]'),
#  Document(metadata={'url': 'https://skepticalscience.com/new_research_2025_52.html', 'date': '2025-12-25', 'source': 'Skepticalscience.com', 'title': 'Skeptical Science New Research for Week #52 2025', 'topic': 'Indian income tax policy'}, page_content='Posted on 25 December 2025 by Doug Bostrom, Marc Kodack\r\nOpen access notables\r\nSatellite altimetry reveals intensifying global river water level variability, Fang et al.,\xa0Nature Communications\r\nRiver… [+40421 chars]'),
#  Document(metadata={'url': 'https://www.cnn.com/2025/12/25/climate/holidays-animals-climate-change-christmas-hanukkah', 'title': 'Nearly half of reindeer have been wiped out and armadillos are in Iowa. Here’s how animals are weathering warming holidays', 'date': '2025-12-25', 'source': 'CNN', 'topic': 'Indian income tax policy'}, page_content='This year is not a particularly white Christmas. Across the United States, families are gathering to enjoy a walk on a warm, sunny day. The fingerprints of climate change are all over the 2025 holida… [+10785 chars]')]

# %%
def build_context(docs, max_chars=3500):
    context = ""
    for doc in docs:
        if len(context) + len(doc.page_content) > max_chars:
            break
        context += doc.page_content + "\n\n"
    return context

context = build_context(docs)
print(f"Context length (chars): {len(context)}")
# Out:
# Context length (chars): 867

# %%
from ollama import Client

client = Client(host="http://localhost:11434")

# %%
def generate_summary(context, topic, intent):
    prompt = f"""
You are a financial news analyst.

Summarize the latest updates related to:
Topic: {topic}
Audience: {intent}

Using ONLY the context below, provide:
1. Key updates (bullet points)
2. Who is affected
3. Why it matters
4. One-line TL;DR

Context:
{context}
"""

    response = client.chat(
        model="llama3.1",
        messages=[{"role": "user", "content": prompt}],
        options={"temperature": 0.2}
    )

    return response["message"]["content"]

# %%
summary = generate_summary(
    context=context,
    topic=topic,
    intent=intent
)

print(summary)
# Out:
# **Key Updates:**
#
# * A hurricane hit Jamaica with wind speeds exceeding 250 mph in recent weeks.
# * The 2025 hurricane season was relatively quiet in the US, with no storms making landfall for the first time since 2015.
# * Climate change is causing unusual weather patterns, including a warm and sunny Christmas across the US.
#
# **Who is Affected:**
#
# * Farmers growing onions in regions affected by the hurricane (e.g. Jamaica) or experiencing unusual weather patterns due to climate change.
#
# **Why it Matters:**
#
# * Unpredictable weather conditions can impact onion yields and quality, affecting farmers' incomes and food supplies.
# * Climate change may lead to more frequent and severe weather events, exacerbating these challenges for farmers.
#
# **One-line TL;DR:**
# Unusual weather patterns in 2025, including a hurricane in Jamaica and a warm Christmas across the US, pose significant risks to onion farmers due to potential crop damage and yield disruptions.
